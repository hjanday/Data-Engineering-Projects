# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"
resource_id = 'f4659cc1-8985-4e4a-a702-ae24352271e0'
url = base_url + "/datastore/dump/" + resource_id
df = pd.read_csv(url)
df
# Out:
#          _id operator_registration_number              address          unit  \
# 0     711155              STR-2301-HBQHHW     137 Danforth Ave             1
# 1     711156              STR-2301-JFDRVZ           6 Park Ave             A
# 2     711157              STR-2304-GKDVHS     63 Ossington Ave        Unit C
# 3     711158              STR-2210-GKZXVG         263 Pape Ave  Laneway Home
# 4     711159              STR-2205-GFGRVF      99 Broadway Ave          1707
# ...      ...                          ...                  ...           ...
# 7977  719132              STR-2401-HTVXVY           14 York St          1901
# 7978  719133              STR-2401-JCBXVZ     1492 Dundas St E             1
# 7979  719134              STR-2401-FQSKVQ     30 Hillsboro Ave          2102
# 7980  719135              STR-2401-GPLKVT  270 Wellington St W           818
# 7981  719136              STR-2401-GGVXVS       37 Waverley Rd           NaN
#
# ...
